# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('white')
# Out:
# //anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
# for easy access to seaborn colors
colorPalette = sns.color_palette()
snsBlue = colorPalette[0]
snsGreen = colorPalette[1]
snsRed = colorPalette[2]
snsPurple = colorPalette[3]
snsYellow = colorPalette[4]
snsAzure = colorPalette[5]
# Out:
# //anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# **Results by method**

# %%
sns.set_context('notebook', font_scale=1.5)

# %%
xx = np.arange(4.0, 11.0, 1.0)
lxx = len(xx)

# %% [markdown]
# *Comparison - number of guesses*

# %%
num_guesses_mean_knuth = np.array([3.0, 3.8, 3.8, 3.9, 3.8, 4.8, 5.4])
num_guesses_mean_rs    = np.array([2.9, 3.5, 3.5, 3.9, 4.3, 4.7, 5.9])
num_guesses_mean_ea    = np.array([2.4, 3.6, 3.4, 3.8, 4.6, 4.8, 5.7])
num_guesses_mean_e     = np.array([3.0, 3.5, 3.5, 4.1, 4.6, 4.7, 5.2])
num_guesses_mean_sab   = np.array([2.9, 4.8, 6.3, 5.3, 6.1, 8.0, 6.7])
num_guesses_mean_sae   = np.array([2.5, 3.2, 3.2, 4.0, 4.8, 4.7, 5.5])
num_guesses_mean_gab   = np.array([2.8, 3.1, 3.7, 3.7, 4.8, 5.0, 5.1])
num_guesses_mean_gae   = np.array([3.1, 3.0, 3.6, 4.0, 4.2, 5.0, 5.2])

# %%
jitter = 0.2

plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_knuth, 'o', color=snsBlue, label="Knuth's algorithm")
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_rs,    'o', color=snsRed, label='Random search')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_sab,   'o', color=snsGreen, label='Simulated annealing')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_gab,   'o', color=snsYellow, label='Genetic algorithms')
plt.ylim(ymin=0, ymax=9)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions (2 possible colors)')
plt.ylabel('Number of guesses')
plt.legend(loc='lower right')
plt.title('Optimization Strategies')
plt.show()

plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_ea,    'o', color=snsBlue, label='Exhaustive search, all steps')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_e,     'o', color=snsRed, label='Exhaustive search, except first step')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_sae,   'o', color=snsGreen, label='Simulated annealing')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_gae,   'o', color=snsYellow, label='Genetic algorithms')
plt.ylim(ymin=0, ymax=6)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions (2 possible colors)')
plt.ylabel('Number of guesses')
plt.legend(loc='lower right')
plt.title('Maximizing Shannon Entropy')
plt.show()

# %%
num_guesses_mean_knuth = np.array([0.001, 0.002, 0.004, 0.015, 0.052, 0.221, 0.803])
num_guesses_mean_rs    = np.array([0.000, 0.001, 0.001, 0.002, 0.004, 0.010, 0.019])
num_guesses_mean_ea    = np.array([0.001, 0.005, 0.016, 0.065, 0.289, 1.323, 5.654])
num_guesses_mean_e     = np.array([0.001, 0.001, 0.001, 0.003, 0.009, 0.026, 0.111])
num_guesses_mean_sab   = np.array([0.001, 0.002, 0.013, 0.008, 0.010, 0.052, 0.147])
num_guesses_mean_sae   = np.array([0.000, 0.001, 0.001, 0.002, 0.005, 0.011, 0.021])
num_guesses_mean_gab   = np.array([0.004, 0.006, 0.009, 0.012, 0.035, 0.047, 0.047])
num_guesses_mean_gae   = np.array([0.006, 0.006, 0.009, 0.015, 0.034, 0.044, 0.080])

# %%
jitter = 0.2

plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_knuth, 'o', color=snsBlue, label="Knuth's algorithm")
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_rs,    'o', color=snsRed, label='Random search')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_sab,   'o', color=snsGreen, label='Simulated annealing')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_gab,   'o', color=snsYellow, label='Genetic algorithms')
plt.ylim(ymin=0, ymax=1.0)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions (2 possible colors)')
plt.ylabel('Runtime (seconds)')
plt.legend(loc='upper left')
plt.title('Optimization Strategies')
plt.show()

plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_ea,    'o', color=snsBlue, label='Exhaustive search, all steps')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_e,     'o', color=snsRed, label='Exhaustive search, except first step')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_sae,   'o', color=snsGreen, label='Simulated annealing')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_gae,   'o', color=snsYellow, label='Genetic algorithms')
plt.ylim(ymin=0, ymax=6)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions (2 possible colors)')
plt.ylabel('Runtime (seconds)')
plt.legend(loc='upper left')
plt.title('Maximizing Entropy')
plt.show()

# %% [markdown]
# *Knuth*

# %%
num_guesses_mean = [3.0, 3.8, 3.8, 3.9, 3.8, 4.8, 5.4]
num_guesses_std  = [0.000, 0.766, 0.748, 0.768, 0.766, 0.766, 0.583]
runtime_mean     = [0.001, 0.002, 0.004, 0.015, 0.052, 0.221, 0.803]
runtime_std      = [0.000, 0.000, 0.002, 0.004, 0.024, 0.074, 0.367]

# %%
plt.errorbar(xx, num_guesses_mean, yerr=num_guesses_std, fmt='o')
plt.ylim(ymin=0, ymax=7)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Number of guesses')
plt.show()

# %%
plt.errorbar(xx, runtime_mean, yerr=runtime_std, fmt='o')
plt.ylim(ymin=0, ymax=1.4)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Runtime (seconds)')
plt.show()

# %% [markdown]
# *Random search*

# %%
num_guesses_mean = [2.9, 3.5, 3.5, 3.9, 4.3, 4.7, 5.9]
num_guesses_std  = [0.624, 0.805, 1.284, 1.261, 1.236, 1.382, 1.261]
runtime_mean     = [0.000, 0.001, 0.001, 0.002, 0.004, 0.010, 0.019]
runtime_std      = [0.000, 0.000, 0.000, 0.000, 0.001, 0.002, 0.002]

# %%
plt.errorbar(xx, num_guesses_mean, yerr=num_guesses_std, fmt='o')
plt.ylim(ymin=0, ymax=8)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Number of guesses')
plt.show()

# %%
plt.errorbar(xx, runtime_mean, yerr=runtime_std, fmt='o')
plt.ylim(ymin=0)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Runtime (seconds)')
plt.show()

# %% [markdown]
# *Maximizing entropy (all steps)*

# %%
num_guesses_mean = [2.4, 3.6, 3.4, 3.8, 4.6, 4.8, 5.7]
num_guesses_std  = [0.800, 1.068, 0.917, 1.208, 0.800, 1.410, 0.792]
runtime_mean     = [0.001, 0.005, 0.016, 0.065, 0.289, 1.323, 5.654]
runtime_std      = [0.000, 0.001, 0.001, 0.004, 0.014, 0.075, 0.339]

# %%
plt.errorbar(xx, num_guesses_mean, yerr=num_guesses_std, fmt='o')
plt.ylim(ymin=0, ymax=7)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Number of guesses')
plt.show()

# %%
plt.errorbar(xx, runtime_mean, yerr=runtime_std, fmt='o')
plt.ylim(ymin=0, ymax=7)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Runtime (seconds)')
plt.show()

# %% [markdown]
# *Maximizing entropy (except first step)*

# %%
num_guesses_mean = [3.0, 3.5, 3.5, 4.1, 4.6, 4.7, 5.2]
num_guesses_std  = [0.921, 1.072, 1.118, 1.136, 1.241, 1.345, 1.178]
runtime_mean     = [0.001, 0.001, 0.001, 0.003, 0.009, 0.026, 0.111]
runtime_std      = [0.000, 0.000, 0.000, 0.001, 0.004, 0.014, 0.061]

# %%
plt.errorbar(xx, num_guesses_mean, yerr=num_guesses_std, fmt='o')
plt.ylim(ymin=0, ymax=7)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Number of guesses')
plt.show()

# %%
plt.errorbar(xx, runtime_mean, yerr=runtime_std, fmt='o')
plt.ylim(ymin=0)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Runtime (seconds)')
plt.show()

# %% [markdown]
# *Simulated annealing (Bernier)*

# %%
num_guesses_mean = [2.9, 4.8, 6.3, 5.3, 6.1, 8.0, 6.7]
num_guesses_std  = [1.091, 2.112, 1.931, 1.590, 2.142, 1.774, 1.878]
runtime_mean     = [0.001, 0.002, 0.013, 0.008, 0.010, 0.052, 0.147]
runtime_std      = [0.001, 0.002, 0.033, 0.012, 0.015, 0.086, 0.453]

# %%
plt.errorbar(xx, num_guesses_mean, yerr=num_guesses_std, fmt='o')
plt.ylim(ymin=0, ymax=10)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Number of guesses')
plt.show()

# %%
plt.errorbar(xx, runtime_mean, yerr=runtime_std, fmt='o')
plt.ylim(ymin=0)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Runtime (seconds)')
plt.show()

# %% [markdown]
# *Simulated annealing (entropy)*

# %%
num_guesses_mean = [2.5, 3.2, 3.2, 4.0, 4.8, 4.7, 5.5]
num_guesses_std  = [0.865, 1.220, 1.327, 1.049, 1.122, 1.345, 1.203]
runtime_mean     = [0.000, 0.001, 0.001, 0.002, 0.005, 0.011, 0.021]
runtime_std      = [0.000, 0.000, 0.000, 0.000, 0.001, 0.002, 0.001]

# %%
plt.errorbar(xx, num_guesses_mean, yerr=num_guesses_std, fmt='o')
plt.ylim(ymin=0, ymax=8)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Number of guesses')
plt.show()

# %%
plt.errorbar(xx, runtime_mean, yerr=runtime_std, fmt='o')
plt.ylim(ymin=0)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Runtime (seconds)')
plt.show()

# %% [markdown]
# *Genetic algorithms (Bernier)*

# %%
num_guesses_mean = [2.8, 3.1, 3.7, 3.7, 4.8, 5.0, 5.1]
num_guesses_std  = [0.812, 0.963, 1.345, 1.054, 0.994, 0.894, 1.179]
runtime_mean     = [0.004, 0.006, 0.009, 0.012, 0.035, 0.047, 0.047]
runtime_std      = [0.002, 0.003, 0.005, 0.013, 0.041, 0.040, 0.085]

# %%
plt.errorbar(xx, num_guesses_mean, yerr=num_guesses_std, fmt='o')
plt.ylim(ymin=0, ymax=7)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Number of guesses')
plt.show()

# %%
plt.errorbar(xx, runtime_mean, yerr=runtime_std, fmt='o')
plt.ylim(ymin=0)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Runtime (seconds)')
plt.show()

# %% [markdown]
# *Genetic algorithms (entropy)*

# %%
num_guesses_mean = [3.1, 3.0, 3.6, 4.0, 4.2, 5.0, 5.2]
num_guesses_std  = [0.943, 1.140, 1.200, 1.342, 1.568, 1.203, 1.260]
runtime_mean     = [0.006, 0.006, 0.009, 0.015, 0.034, 0.044, 0.080]
runtime_std      = [0.003, 0.004, 0.004, 0.009, 0.025, 0.026, 0.072]

# %%
plt.errorbar(xx, num_guesses_mean, yerr=num_guesses_std, fmt='o')
plt.ylim(ymin=0, ymax=7)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions')
plt.ylabel('Number of guesses')
plt.show()

# %%
plt.errorbar(xx, runtime_mean, yerr=runtime_std, fmt='o')
plt.ylim(ymin=0)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of possible digits')
plt.ylabel('Runtime (seconds)')
plt.show()
