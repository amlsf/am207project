# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('white')
# Out:
# //anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
# for easy access to seaborn colors
colorPalette = sns.color_palette()
snsBlue = colorPalette[0]
snsGreen = colorPalette[1]
snsRed = colorPalette[2]
snsPurple = colorPalette[3]
snsYellow = colorPalette[4]
snsAzure = colorPalette[5]
# Out:
# //anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
sns.set_context('poster')
sns.set_style({'font.family': [u'serif'],
               'font.variant': 'small-caps'})

# %%
xx = np.arange(4.0, 11.0, 1.0)
lxx = len(xx)

# %% [markdown]
# *Comparison - by color*

# %%
num_guesses_mean_knuth = np.array([4.0, 4.0, 4.0, 4.0, 6.0, 6.0, 6.0])
num_guesses_mean_rs    = np.array([3.7, 4.5, 4.8, 5.0, 5.4, 5.9, 6.6])
num_guesses_mean_ea    = np.array([3.8, 4.0, 4.8, 4.8, 5.1, 5.8, 5.8])
num_guesses_mean_e     = np.array([3.7, 4.0, 4.4, 4.8, 5.4, 5.7, 6.0])
num_guesses_mean_sab   = np.array([7.5, 8.0, 8.0, 9.2, 9.1, 8.8, 9.4])
num_guesses_mean_sae   = np.array([3.5, 4.7, 5.0, 5.3, 5.5, 6.2, 6.0])
num_guesses_mean_gab   = np.array([3.9, 4.0, 4.8, 5.0, 5.3, 6.0, 6.5])
num_guesses_mean_gae   = np.array([3.8, 4.5, 5.0, 5.5, 5.5, 6.2, 5.9])

# %%
jitter = 0.2

plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_knuth, 'o',
         color=sns.xkcd_rgb['blue'], label="Knuth's algorithm")
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_rs,    'o',
         color=sns.xkcd_rgb['light red'], label='Random search with constraints')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_sab,   'o',
         color=sns.xkcd_rgb['purple'], label='Simulated annealing')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_gab,   'o',
         color=sns.xkcd_rgb['grass green'], label='Genetic algorithms')
plt.ylim(ymin=0, ymax=10)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of possible colors (4 positions)')
plt.ylabel('Number of guesses')
plt.legend(loc='lower right')
plt.title('Optimization Strategies')
plt.show()

plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_ea,    'o', 
         color=sns.xkcd_rgb['blue'], label='Exhaustive search, all steps')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_e,     'o', 
         color=sns.xkcd_rgb['light red'], label='Exhaustive search, except first step')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_sae,   'o', 
         color=sns.xkcd_rgb['purple'], label='Simulated annealing')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_gae,   'o', 
         color=sns.xkcd_rgb['grass green'], label='Genetic algorithms')
plt.ylim(ymin=0, ymax=7)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of possible colors (4 positions)')
plt.ylabel('Number of guesses')
plt.legend(loc='lower right')
plt.title('Maximizing Shannon Entropy')
plt.show()

# %%
num_guesses_mean_knuth = np.array([0.021, 0.264, 0.606, 0.528, 21.711, 67.299, 84.160])
num_guesses_mean_rs    = np.array([0.002, 0.006, 0.013, 0.023, 0.044, 0.069, 0.098])
num_guesses_mean_ea    = np.array([0.193, 1.147, 5.225, 18.600, 53.689, 149.057, 344.603])
num_guesses_mean_e     = np.array([0.007, 0.042, 0.145, 0.669, 1.464, 5.702, 13.557])
num_guesses_mean_sab   = np.array([0.017, 0.042, 0.268, 0.069, 0.290, 0.191, 0.248])
num_guesses_mean_sae   = np.array([0.003, 0.007, 0.013, 0.028, 0.043, 0.091, 0.127])
num_guesses_mean_gab   = np.array([0.022, 0.160, 0.230, 2.432, 25.809, 66.406, 77.632])
num_guesses_mean_gae   = np.array([0.027, 0.273, 0.376, 1.384, 7.866, 10.492, 107.604])

# %%
jitter = 0.2

plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_knuth, 'o', 
         color=sns.xkcd_rgb['blue'], label="Knuth's algorithm")
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_rs,    'o', 
         color=sns.xkcd_rgb['light red'], label='Random search with constraints')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_sab,   'o', 
         color=sns.xkcd_rgb['purple'], label='Simulated annealing')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_gab,   'o', 
         color=sns.xkcd_rgb['grass green'], label='Genetic algorithms')
plt.ylim(ymin=0, ymax=90)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of possible colors (4 positions)')
plt.ylabel('Runtime (seconds)')
plt.legend(loc='upper left')
plt.title('Optimization Strategies')
plt.show()

plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_ea,    'o', 
         color=sns.xkcd_rgb['blue'], label='Exhaustive search, all steps')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_e,     'o', 
         color=sns.xkcd_rgb['light red'], label='Exhaustive search, except first step')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_sae,   'o', 
         color=sns.xkcd_rgb['purple'], label='Simulated annealing')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_gae,   'o', 
         color=sns.xkcd_rgb['grass green'], label='Genetic algorithms')
plt.ylim(ymin=0, ymax=350)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of possible colors (4 positions)')
plt.ylabel('Runtime (seconds)')
plt.legend(loc='upper left')
plt.title('Maximizing Shannon Entropy')
plt.show()

# %% [markdown]
# *Comparison - by length*

# %%
num_guesses_mean_knuth = np.array([3.0, 3.8, 3.8, 3.9, 3.8, 4.8, 5.4])
num_guesses_mean_rs    = np.array([2.9, 3.5, 3.5, 3.9, 4.3, 4.7, 5.9])
num_guesses_mean_ea    = np.array([2.4, 3.6, 3.4, 3.8, 4.6, 4.8, 5.7])
num_guesses_mean_e     = np.array([3.0, 3.5, 3.5, 4.1, 4.6, 4.7, 5.2])
num_guesses_mean_sab   = np.array([2.9, 4.8, 6.3, 5.3, 6.1, 8.0, 6.7])
num_guesses_mean_sae   = np.array([2.5, 3.2, 3.2, 4.0, 4.8, 4.7, 5.5])
num_guesses_mean_gab   = np.array([2.8, 3.1, 3.7, 3.7, 4.8, 5.0, 5.1])
num_guesses_mean_gae   = np.array([3.1, 3.0, 3.6, 4.0, 4.2, 5.0, 5.2])

# %%
jitter = 0.2

plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_knuth, 'o', 
         color=sns.xkcd_rgb['blue'], label="Knuth's algorithm")
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_rs,    'o', 
         color=sns.xkcd_rgb['light red'], label='Random search with constraints')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_sab,   'o', 
         color=sns.xkcd_rgb['purple'], label='Simulated annealing')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_gab,   'o', 
         color=sns.xkcd_rgb['grass green'], label='Genetic algorithms')
plt.ylim(ymin=0, ymax=9)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions (2 possible colors)')
plt.ylabel('Number of guesses')
plt.legend(loc='lower right')
plt.title('Optimization Strategies')
plt.show()

plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_ea,    'o', 
         color=sns.xkcd_rgb['blue'], label='Exhaustive search, all steps')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_e,     'o', 
         color=sns.xkcd_rgb['light red'], label='Exhaustive search, except first step')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_sae,   'o', 
         color=sns.xkcd_rgb['purple'], label='Simulated annealing')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_gae,   'o', 
         color=sns.xkcd_rgb['grass green'], label='Genetic algorithms')
plt.ylim(ymin=0, ymax=6)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions (2 possible colors)')
plt.ylabel('Number of guesses')
plt.legend(loc='lower right')
plt.title('Maximizing Shannon Entropy')
plt.show()

# %%
num_guesses_mean_knuth = np.array([0.001, 0.002, 0.004, 0.015, 0.052, 0.221, 0.803])
num_guesses_mean_rs    = np.array([0.000, 0.001, 0.001, 0.002, 0.004, 0.010, 0.019])
num_guesses_mean_ea    = np.array([0.001, 0.005, 0.016, 0.065, 0.289, 1.323, 5.654])
num_guesses_mean_e     = np.array([0.001, 0.001, 0.001, 0.003, 0.009, 0.026, 0.111])
num_guesses_mean_sab   = np.array([0.001, 0.002, 0.013, 0.008, 0.010, 0.052, 0.147])
num_guesses_mean_sae   = np.array([0.000, 0.001, 0.001, 0.002, 0.005, 0.011, 0.021])
num_guesses_mean_gab   = np.array([0.004, 0.006, 0.009, 0.012, 0.035, 0.047, 0.047])
num_guesses_mean_gae   = np.array([0.006, 0.006, 0.009, 0.015, 0.034, 0.044, 0.080])

# %%
jitter = 0.2

plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_knuth, 'o',
         color=sns.xkcd_rgb['blue'], label="Knuth's algorithm")
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_rs,    'o', 
         color=sns.xkcd_rgb['light red'], label='Random search with constraints')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_sab,   'o',
         color=sns.xkcd_rgb['purple'], label='Simulated annealing')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_gab,   'o', 
         color=sns.xkcd_rgb['grass green'], label='Genetic algorithms')
plt.ylim(ymin=0, ymax=1.0)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions (2 possible colors)')
plt.ylabel('Runtime (seconds)')
plt.legend(loc='upper left')
plt.title('Optimization Strategies')
plt.show()

plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_ea,    'o', 
         color=sns.xkcd_rgb['blue'], label='Exhaustive search, all steps')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_e,     'o', 
         color=sns.xkcd_rgb['light red'], label='Exhaustive search, except first step')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_sae,   'o', 
         color=sns.xkcd_rgb['purple'], label='Simulated annealing')
plt.plot(xx + np.random.uniform(-jitter, jitter), num_guesses_mean_gae,   'o', 
         color=sns.xkcd_rgb['grass green'], label='Genetic algorithms')
plt.ylim(ymin=0, ymax=6)
plt.xlim(xmin=(min(xx)-0.5), xmax=(max(xx)+0.5))
plt.xlabel('Number of positions (2 possible colors)')
plt.ylabel('Runtime (seconds)')
plt.legend(loc='upper left')
plt.title('Maximizing Entropy')
plt.show()
